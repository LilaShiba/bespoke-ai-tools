# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import os
import datetime
import glob
from pathlib import Path

# %%
folder_path = Path("/Users/lila/sp00kyvectors/sp00kyvectors/notbooks/data")
all_files = glob.glob(os.path.join(folder_path, "*.csv"))
all_dfs = []
# Append the rest of the CSVs without headers
for file in all_files:
    df = pd.read_csv(file)
    all_dfs.append(df)

# %%
combined_df = pd.concat(all_dfs, ignore_index=True)

# %%
combined_df.info()

# %%
len(combined_df)

# %%
combined_df['Timestamp'].unique()

# %%
df = combined_df[~combined_df['Timestamp'].apply(lambda x: isinstance(x, float))]

# %%
df.describe()

# %%
df.shape

# %%
df = df.sort_values(by='Timestamp')

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Timestamp'], df['Humidity'], marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('Humidity')
plt.title('Humidity Over Time')
plt.show()

# %%
# !pip install sp00kyVectors
# Out:
# /Users/lila/.zshenv:1: command not found: Loading
# ERROR: Could not find a version that satisfies the requirement sp00kyVectors (from versions: none)
# ERROR: No matching distribution found for sp00kyVectors
